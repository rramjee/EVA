# %% [markdown]
# <a href="https://colab.research.google.com/github/deepjyotisaha85/eva4/blob/master/session15/S15_SamplePredict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import sys
workingdir = '/content/gdrive/My Drive/Colab Notebooks/EVA4/S15-final'
sys.path.append(workingdir)

# %%
from utils import predict

# %%
MODELPATH = '/content/gdrive/My Drive/Colab Notebooks/EVA4/S15-final/finalmodel/predict_mask_and_depthmap.pth'
FILEPATH = '/content/gdrive/My Drive/Colab Notebooks/EVA4/S15-final/testimg/'

# %%
bg = 'test_bg_1.jpg'
image = 'test_img_1.jpg'
predict.predict_images(MODELPATH, FILEPATH, bg,  image)

# %%
bg = 'test_bg_2.jpg'
image = 'test_img_2.jpg'
predict.predict_images(MODELPATH, FILEPATH, bg,  image)
