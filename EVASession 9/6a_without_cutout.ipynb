# %%
#Loading all the libraries
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils

# %%
#importing cifar 10 database from cs.toronto.edu website.
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
#browsing through the dataset and viewing the data
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
# user defined function to plot the comaprison between test and train accuracy and error
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
#user defined function to calculate accuracy 

def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
# Pixel normaization 
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
# Define the model
#layers are added to follow the expand and squeeze methodogy. added activation as separate step. #drop oout of 0.1 and bacth normalization
model = Sequential()
model.add(Convolution2D(32, 3, 3, name='layer1',border_mode='same', input_shape=(32, 32, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Convolution2D(64, 3, 3, name='layer2',border_mode='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))


model.add(Convolution2D(128, 3, 3, name='layer3', border_mode='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Convolution2D(10, 1, 1,name='layer4')) 
model.add(MaxPooling2D(pool_size=(2, 2)))



model.add(Convolution2D(32, 3, 3,name='layer5', border_mode='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Convolution2D(64, 3, 3, name='layer6',border_mode='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

model.add(Convolution2D(10, 1, 1,name='layer7')) 
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Convolution2D(32, 3, 3, name='layer8',border_mode='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Convolution2D(64, 3, 3, name='layer9',border_mode='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Convolution2D(96, 3, 3,name='layer10', border_mode='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))


model.add(Convolution2D(10, 8, 8,name='layer11'))

#Removing Max pooling from last layer
#model.add(MaxPooling2D(pool_size=(2, 2)))
#Removing Dropout from the last layer
#model.add(Dropout(0.25))

#Removing Dense Layer as suggested and replaced with flatten layer
#model.add(Flatten())
#model.add(Dense(512))
#model.add(Activation('relu'))
#model.add(Dropout(0.5))
#model.add(Dense(256))
#model.add(Activation('relu'))

#model.add(Dropout(0.5))

#model.add(Dense(num_classes, activation='softmax'))

model.add(Flatten())
model.add(Activation('softmax'))
# Compile the model
#model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0625 06:54:07.282738 140095806781312 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), name="layer1", input_shape=(32, 32, 3..., padding="same")`
#
# W0625 06:54:07.328139 140095806781312 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0625 06:54:07.336066 140095806781312 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0625 06:54:07.381371 140095806781312 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0625 06:54:07.382455 140095806781312 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0625 06:54:10.268237 140095806781312 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0625 06:54:10.350296 140095806781312 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), name="layer2", padding="same")`
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), name="layer3", padding="same")`
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1), name="layer4")`
# W0625 06:54:10.723687 140095806781312 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), name="layer5", padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), name="layer6", padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:36: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1), name="layer7")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), name="layer8", padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), name="layer9", padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), name="layer10", padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:55: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (8, 8), name="layer11")`

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# layer2 (Conv2D)              (None, 32, 32, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# layer3 (Conv2D)              (None, 32, 32, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 32, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32, 32, 128)       0
# _________________________________________________________________
# layer4 (Conv2D)              (None, 32, 32, 10)        1290
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 10)        0
# _________________________________________________________________
# layer5 (Conv2D)              (None, 16, 16, 32)        2912
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# layer6 (Conv2D)              (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_5 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# layer7 (Conv2D)              (None, 16, 16, 10)        650
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 10)          0
# _________________________________________________________________
# layer8 (Conv2D)              (None, 8, 8, 32)          2912
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 32)          128
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 32)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 8, 8, 32)          0
# _________________________________________________________________
# layer9 (Conv2D)              (None, 8, 8, 64)          18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_7 (Activation)    (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# layer10 (Conv2D)             (None, 8, 8, 96)          55392
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 96)          384
# _________________________________________________________________
# activation_8 (Activation)    (None, 8, 8, 96)          0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 8, 8, 96)          0
# _________________________________________________________________
# layer11 (Conv2D)             (None, 1, 1, 10)          61450
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_9 (Activation)    (None, 10)                0
# =================================================================
# Total params: 256,894
# Trainable params: 255,870
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
from keras.optimizers import Adam, SGD
from keras.callbacks import LearningRateScheduler
def scheduler(epoch, lr):
  return round(0.003 * 1/(1 + 0.319 * epoch), 10)

#model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.003), metrics=['accuracy'])

# %%
# Retrieve the saved best results
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#This is to store the weights of the best accuracy to mounted drive
from keras.callbacks import ModelCheckpoint
filepath="/content/gdrive/My Drive/Ramjee-EVA9A_{epoch:02d}-{val_acc:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc',verbose=1, mode='max')
callbacks_list = [checkpoint]

# %%
#Assignment.
#using learning rate, running fit_generator function to run for 100 epochs.
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.003), metrics=['accuracy'])
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1,callbacks=callbacks_list)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# W0625 06:54:59.655276 140095806781312 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=100)`
#   del sys.path[0]
# W0625 06:54:59.792175 140095806781312 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 390/390 [==============================] - 30s 78ms/step - loss: 2.0644 - acc: 0.3271 - val_loss: 2.1537 - val_acc: 0.3238
#
# Epoch 00001: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_01-0.32.hdf5
# Epoch 2/100
# 390/390 [==============================] - 25s 64ms/step - loss: 1.3195 - acc: 0.5263 - val_loss: 1.5416 - val_acc: 0.4832
#
# Epoch 00002: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_02-0.48.hdf5
# Epoch 3/100
# 390/390 [==============================] - 39s 101ms/step - loss: 1.0751 - acc: 0.6168 - val_loss: 1.0855 - val_acc: 0.6146
#
# Epoch 00003: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_03-0.61.hdf5
# Epoch 4/100
# 390/390 [==============================] - 44s 113ms/step - loss: 0.9439 - acc: 0.6652 - val_loss: 0.9266 - val_acc: 0.6762
#
# Epoch 00004: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_04-0.68.hdf5
# Epoch 5/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.8424 - acc: 0.7049 - val_loss: 0.9845 - val_acc: 0.6611
#
# Epoch 00005: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_05-0.66.hdf5
# Epoch 6/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.7578 - acc: 0.7338 - val_loss: 0.9221 - val_acc: 0.6793
#
# Epoch 00006: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_06-0.68.hdf5
# Epoch 7/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.6959 - acc: 0.7588 - val_loss: 0.7844 - val_acc: 0.7257
#
# Epoch 00007: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_07-0.73.hdf5
# Epoch 8/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.6529 - acc: 0.7717 - val_loss: 0.8112 - val_acc: 0.7177
#
# Epoch 00008: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_08-0.72.hdf5
# Epoch 9/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.6027 - acc: 0.7891 - val_loss: 0.8013 - val_acc: 0.7249
#
# Epoch 00009: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_09-0.72.hdf5
# Epoch 10/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.5629 - acc: 0.8047 - val_loss: 0.7351 - val_acc: 0.7472
#
# Epoch 00010: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_10-0.75.hdf5
# Epoch 11/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.5316 - acc: 0.8134 - val_loss: 0.6635 - val_acc: 0.7695
#
# Epoch 00011: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_11-0.77.hdf5
# Epoch 12/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.5030 - acc: 0.8226 - val_loss: 0.6048 - val_acc: 0.7948
#
# Epoch 00012: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_12-0.79.hdf5
# Epoch 13/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.4770 - acc: 0.8335 - val_loss: 0.6541 - val_acc: 0.7813
#
# Epoch 00013: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_13-0.78.hdf5
# Epoch 14/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.4466 - acc: 0.8427 - val_loss: 0.6321 - val_acc: 0.7912
#
# Epoch 00014: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_14-0.79.hdf5
# Epoch 15/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.4293 - acc: 0.8499 - val_loss: 0.6660 - val_acc: 0.7764
#
# Epoch 00015: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_15-0.78.hdf5
# Epoch 16/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.4080 - acc: 0.8554 - val_loss: 0.6419 - val_acc: 0.7951
#
# Epoch 00016: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_16-0.80.hdf5
# Epoch 17/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.3855 - acc: 0.8642 - val_loss: 0.6258 - val_acc: 0.7959
#
# Epoch 00017: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_17-0.80.hdf5
# Epoch 18/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.3817 - acc: 0.8644 - val_loss: 0.7304 - val_acc: 0.7690
#
# Epoch 00018: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_18-0.77.hdf5
# Epoch 19/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.3555 - acc: 0.8734 - val_loss: 0.8207 - val_acc: 0.7590
#
# Epoch 00019: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_19-0.76.hdf5
# Epoch 20/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.3427 - acc: 0.8789 - val_loss: 0.7979 - val_acc: 0.7566
#
# Epoch 00020: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_20-0.76.hdf5
# Epoch 21/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.3297 - acc: 0.8819 - val_loss: 0.6450 - val_acc: 0.8026
#
# Epoch 00021: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_21-0.80.hdf5
# Epoch 22/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.3165 - acc: 0.8870 - val_loss: 0.7441 - val_acc: 0.7737
#
# Epoch 00022: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_22-0.77.hdf5
# Epoch 23/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.3014 - acc: 0.8932 - val_loss: 0.6687 - val_acc: 0.7954
#
# Epoch 00023: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_23-0.80.hdf5
# Epoch 24/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.2913 - acc: 0.8943 - val_loss: 0.6355 - val_acc: 0.8082
#
# Epoch 00024: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_24-0.81.hdf5
# Epoch 25/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.2889 - acc: 0.8958 - val_loss: 0.6386 - val_acc: 0.8067
#
# Epoch 00025: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_25-0.81.hdf5
# Epoch 26/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.2690 - acc: 0.9025 - val_loss: 0.7481 - val_acc: 0.7842
#
# Epoch 00026: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_26-0.78.hdf5
# Epoch 27/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.2640 - acc: 0.9061 - val_loss: 0.6520 - val_acc: 0.8028
#
# Epoch 00027: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_27-0.80.hdf5
# Epoch 28/100
# 390/390 [==============================] - 46s 118ms/step - loss: 0.2564 - acc: 0.9074 - val_loss: 0.6712 - val_acc: 0.8097
#
# Epoch 00028: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_28-0.81.hdf5
# Epoch 29/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.2509 - acc: 0.9096 - val_loss: 0.7258 - val_acc: 0.7873
#
# Epoch 00029: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_29-0.79.hdf5
# Epoch 30/100
# 390/390 [==============================] - 46s 118ms/step - loss: 0.2499 - acc: 0.9100 - val_loss: 0.7929 - val_acc: 0.7813
#
# Epoch 00030: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_30-0.78.hdf5
# Epoch 31/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.2362 - acc: 0.9148 - val_loss: 0.8700 - val_acc: 0.7683
#
# Epoch 00031: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_31-0.77.hdf5
# Epoch 32/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.2269 - acc: 0.9177 - val_loss: 0.8143 - val_acc: 0.7837
#
# Epoch 00032: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_32-0.78.hdf5
# Epoch 33/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.2298 - acc: 0.9172 - val_loss: 0.6916 - val_acc: 0.8015
#
# Epoch 00033: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_33-0.80.hdf5
# Epoch 34/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.2175 - acc: 0.9220 - val_loss: 0.7341 - val_acc: 0.7950
#
# Epoch 00034: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_34-0.80.hdf5
# Epoch 35/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.2134 - acc: 0.9222 - val_loss: 0.7740 - val_acc: 0.7913
#
# Epoch 00035: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_35-0.79.hdf5
# Epoch 36/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.2094 - acc: 0.9228 - val_loss: 0.7181 - val_acc: 0.8046
#
# Epoch 00036: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_36-0.80.hdf5
# Epoch 37/100
# 390/390 [==============================] - 45s 115ms/step - loss: 0.2085 - acc: 0.9244 - val_loss: 0.6892 - val_acc: 0.8094
#
# Epoch 00037: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_37-0.81.hdf5
# Epoch 38/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.2001 - acc: 0.9262 - val_loss: 0.7340 - val_acc: 0.8043
#
# Epoch 00038: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_38-0.80.hdf5
# Epoch 39/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1946 - acc: 0.9300 - val_loss: 0.7171 - val_acc: 0.8136
#
# Epoch 00039: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_39-0.81.hdf5
# Epoch 40/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1925 - acc: 0.9301 - val_loss: 0.7631 - val_acc: 0.8018
#
# Epoch 00040: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_40-0.80.hdf5
# Epoch 41/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.1856 - acc: 0.9325 - val_loss: 0.7219 - val_acc: 0.8114
#
# Epoch 00041: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_41-0.81.hdf5
# Epoch 42/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1853 - acc: 0.9330 - val_loss: 0.7163 - val_acc: 0.8146
#
# Epoch 00042: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_42-0.81.hdf5
# Epoch 43/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1806 - acc: 0.9336 - val_loss: 0.7650 - val_acc: 0.8041
#
# Epoch 00043: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_43-0.80.hdf5
# Epoch 44/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1827 - acc: 0.9339 - val_loss: 0.6853 - val_acc: 0.8127
#
# Epoch 00044: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_44-0.81.hdf5
# Epoch 45/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1743 - acc: 0.9362 - val_loss: 0.7027 - val_acc: 0.8107
#
# Epoch 00045: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_45-0.81.hdf5
# Epoch 46/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1685 - acc: 0.9385 - val_loss: 0.8625 - val_acc: 0.7832
#
# Epoch 00046: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_46-0.78.hdf5
# Epoch 47/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1679 - acc: 0.9378 - val_loss: 0.7571 - val_acc: 0.8085
#
# Epoch 00047: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_47-0.81.hdf5
# Epoch 48/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1691 - acc: 0.9380 - val_loss: 0.7708 - val_acc: 0.8035
#
# Epoch 00048: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_48-0.80.hdf5
# Epoch 49/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1651 - acc: 0.9409 - val_loss: 0.7574 - val_acc: 0.8142
#
# Epoch 00049: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_49-0.81.hdf5
# Epoch 50/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1607 - acc: 0.9415 - val_loss: 0.7723 - val_acc: 0.8010
#
# Epoch 00050: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_50-0.80.hdf5
# Epoch 51/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.1579 - acc: 0.9424 - val_loss: 0.7207 - val_acc: 0.8187
#
# Epoch 00051: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_51-0.82.hdf5
# Epoch 52/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1574 - acc: 0.9435 - val_loss: 0.7665 - val_acc: 0.8129
#
# Epoch 00052: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_52-0.81.hdf5
# Epoch 53/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1524 - acc: 0.9453 - val_loss: 0.7300 - val_acc: 0.8133
#
# Epoch 00053: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_53-0.81.hdf5
# Epoch 54/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1598 - acc: 0.9431 - val_loss: 0.8373 - val_acc: 0.7928
#
# Epoch 00054: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_54-0.79.hdf5
# Epoch 55/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.1506 - acc: 0.9461 - val_loss: 0.7747 - val_acc: 0.8090
#
# Epoch 00055: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_55-0.81.hdf5
# Epoch 56/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1472 - acc: 0.9475 - val_loss: 0.7619 - val_acc: 0.8049
#
# Epoch 00056: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_56-0.80.hdf5
# Epoch 57/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1493 - acc: 0.9451 - val_loss: 0.8550 - val_acc: 0.7857
#
# Epoch 00057: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_57-0.79.hdf5
# Epoch 58/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1472 - acc: 0.9476 - val_loss: 0.7937 - val_acc: 0.8078
#
# Epoch 00058: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_58-0.81.hdf5
# Epoch 59/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1432 - acc: 0.9487 - val_loss: 0.7782 - val_acc: 0.8140
#
# Epoch 00059: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_59-0.81.hdf5
# Epoch 60/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1454 - acc: 0.9470 - val_loss: 0.7967 - val_acc: 0.8064
#
# Epoch 00060: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_60-0.81.hdf5
# Epoch 61/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1395 - acc: 0.9497 - val_loss: 0.9385 - val_acc: 0.7850
#
# Epoch 00061: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_61-0.79.hdf5
# Epoch 62/100
# 390/390 [==============================] - 45s 115ms/step - loss: 0.1395 - acc: 0.9510 - val_loss: 0.8135 - val_acc: 0.8066
#
# Epoch 00062: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_62-0.81.hdf5
# Epoch 63/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1372 - acc: 0.9494 - val_loss: 0.7900 - val_acc: 0.8082
#
# Epoch 00063: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_63-0.81.hdf5
# Epoch 64/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1336 - acc: 0.9507 - val_loss: 0.7761 - val_acc: 0.8165
#
# Epoch 00064: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_64-0.82.hdf5
# Epoch 65/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1324 - acc: 0.9520 - val_loss: 0.8166 - val_acc: 0.8078
#
# Epoch 00065: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_65-0.81.hdf5
# Epoch 66/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1319 - acc: 0.9533 - val_loss: 0.8301 - val_acc: 0.7974
#
# Epoch 00066: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_66-0.80.hdf5
# Epoch 67/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1342 - acc: 0.9509 - val_loss: 0.7846 - val_acc: 0.8067
#
# Epoch 00067: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_67-0.81.hdf5
# Epoch 68/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1268 - acc: 0.9540 - val_loss: 0.8397 - val_acc: 0.8099
#
# Epoch 00068: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_68-0.81.hdf5
# Epoch 69/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1296 - acc: 0.9533 - val_loss: 0.8464 - val_acc: 0.8043
#
# Epoch 00069: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_69-0.80.hdf5
# Epoch 70/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1286 - acc: 0.9537 - val_loss: 0.9578 - val_acc: 0.7850
#
# Epoch 00070: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_70-0.79.hdf5
# Epoch 71/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.1285 - acc: 0.9541 - val_loss: 0.7686 - val_acc: 0.8195
#
# Epoch 00071: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_71-0.82.hdf5
# Epoch 72/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1269 - acc: 0.9539 - val_loss: 0.7838 - val_acc: 0.8218
#
# Epoch 00072: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_72-0.82.hdf5
# Epoch 73/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1232 - acc: 0.9564 - val_loss: 0.8447 - val_acc: 0.8113
#
# Epoch 00073: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_73-0.81.hdf5
# Epoch 74/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1269 - acc: 0.9539 - val_loss: 0.8087 - val_acc: 0.8185
#
# Epoch 00074: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_74-0.82.hdf5
# Epoch 75/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1212 - acc: 0.9566 - val_loss: 0.8054 - val_acc: 0.8184
#
# Epoch 00075: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_75-0.82.hdf5
# Epoch 76/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.1201 - acc: 0.9566 - val_loss: 0.7937 - val_acc: 0.8186
#
# Epoch 00076: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_76-0.82.hdf5
# Epoch 77/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1181 - acc: 0.9577 - val_loss: 0.7737 - val_acc: 0.8249
#
# Epoch 00077: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_77-0.82.hdf5
# Epoch 78/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.1240 - acc: 0.9555 - val_loss: 0.7982 - val_acc: 0.8219
#
# Epoch 00078: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_78-0.82.hdf5
# Epoch 79/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1159 - acc: 0.9577 - val_loss: 0.8713 - val_acc: 0.8048
#
# Epoch 00079: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_79-0.80.hdf5
# Epoch 80/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1191 - acc: 0.9578 - val_loss: 0.8294 - val_acc: 0.8107
#
# Epoch 00080: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_80-0.81.hdf5
# Epoch 81/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1155 - acc: 0.9585 - val_loss: 0.8936 - val_acc: 0.7954
#
# Epoch 00081: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_81-0.80.hdf5
# Epoch 82/100
# 390/390 [==============================] - 45s 115ms/step - loss: 0.1205 - acc: 0.9568 - val_loss: 0.7976 - val_acc: 0.8200
#
# Epoch 00082: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_82-0.82.hdf5
# Epoch 83/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1145 - acc: 0.9591 - val_loss: 0.8132 - val_acc: 0.8121
#
# Epoch 00083: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_83-0.81.hdf5
# Epoch 84/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1104 - acc: 0.9598 - val_loss: 0.8151 - val_acc: 0.8212
#
# Epoch 00084: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_84-0.82.hdf5
# Epoch 85/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1127 - acc: 0.9596 - val_loss: 0.8033 - val_acc: 0.8181
#
# Epoch 00085: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_85-0.82.hdf5
# Epoch 86/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1100 - acc: 0.9603 - val_loss: 0.8390 - val_acc: 0.8153
#
# Epoch 00086: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_86-0.82.hdf5
# Epoch 87/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.1071 - acc: 0.9611 - val_loss: 0.9216 - val_acc: 0.8083
#
# Epoch 00087: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_87-0.81.hdf5
# Epoch 88/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1127 - acc: 0.9598 - val_loss: 0.8011 - val_acc: 0.8192
#
# Epoch 00088: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_88-0.82.hdf5
# Epoch 89/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1142 - acc: 0.9602 - val_loss: 0.8027 - val_acc: 0.8216
#
# Epoch 00089: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_89-0.82.hdf5
# Epoch 90/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1049 - acc: 0.9621 - val_loss: 0.8015 - val_acc: 0.8217
#
# Epoch 00090: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_90-0.82.hdf5
# Epoch 91/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1125 - acc: 0.9593 - val_loss: 0.9275 - val_acc: 0.7997
#
# Epoch 00091: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_91-0.80.hdf5
# Epoch 92/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.1092 - acc: 0.9610 - val_loss: 0.8154 - val_acc: 0.8182
#
# Epoch 00092: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_92-0.82.hdf5
# Epoch 93/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1063 - acc: 0.9609 - val_loss: 0.8127 - val_acc: 0.8252
#
# Epoch 00093: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_93-0.83.hdf5
# Epoch 94/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1063 - acc: 0.9622 - val_loss: 0.8221 - val_acc: 0.8146
#
# Epoch 00094: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_94-0.81.hdf5
# Epoch 95/100
# 390/390 [==============================] - 46s 117ms/step - loss: 0.1032 - acc: 0.9628 - val_loss: 0.8047 - val_acc: 0.8226
#
# Epoch 00095: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_95-0.82.hdf5
# Epoch 96/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1027 - acc: 0.9627 - val_loss: 0.8937 - val_acc: 0.8006
#
# Epoch 00096: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_96-0.80.hdf5
# Epoch 97/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.1081 - acc: 0.9614 - val_loss: 0.8105 - val_acc: 0.8232
#
# Epoch 00097: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_97-0.82.hdf5
# Epoch 98/100
# 390/390 [==============================] - 45s 117ms/step - loss: 0.1015 - acc: 0.9650 - val_loss: 0.8413 - val_acc: 0.8170
#
# Epoch 00098: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_98-0.82.hdf5
# Epoch 99/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.0998 - acc: 0.9642 - val_loss: 0.8699 - val_acc: 0.8149
#
# Epoch 00099: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_99-0.81.hdf5
# Epoch 100/100
# 390/390 [==============================] - 45s 116ms/step - loss: 0.1066 - acc: 0.9622 - val_loss: 0.7945 - val_acc: 0.8299
#
# Epoch 00100: saving model to /content/gdrive/My Drive/Ramjee-EVA9A_100-0.83.hdf5
# Model took 4549.30 seconds to train
# Accuracy on test data is: 82.99

# %%
model.save
# Out:
# <bound method Network.save of <keras.engine.sequential.Sequential object at 0x7f6a4c5b6b70>>

# %%
modelpath = "/content/gdrive/My Drive/EVAModel9.json"
model_json = model.to_json()
with open(modelpath,"w") as json_file:
  json_file.write(model_json)
